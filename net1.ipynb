# %%
import torch

torch.__version__
# Out:
# '2.9.1'

# %%
size = 500

# %%
a = m = torch.ones(size, size)
b = m = torch.ones(size, size)

# %timeit a @ b
# Out:
# 151 μs ± 422 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
a = m = torch.ones(size, size).to("mps")
b = m = torch.ones(size, size).to("mps")

# %timeit a @ b
# Out:
# 94.5 μs ± 2.58 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
